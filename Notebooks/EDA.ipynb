# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('../Dataset/Mapping/dataset_mapping.csv')
dataset.head()
# Out:
#          file_name plant_type             label
# 0    image (1).JPG      Apple  Apple_Apple_scab
# 1   image (10).JPG      Apple  Apple_Apple_scab
# 2  image (100).JPG      Apple  Apple_Apple_scab
# 3  image (101).JPG      Apple  Apple_Apple_scab
# 4  image (102).JPG      Apple  Apple_Apple_scab

# %%
dataset["plant_type"].value_counts().plot(kind='bar')
plt.show()

# %%
dataset["label"].value_counts().plot(kind='bar')
plt.show()
